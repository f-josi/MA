# %% [markdown]
# *Copyright:
# Prof. Dr. Christian Wartena, http://textmining.wp.hs-hannover.de/; Frieda Josi*

# %% [markdown]
# ## Termextraktion
# Die Frequenz der Terme mit der Wortart NN (Nomen) und VB (Verb in seiner Stammform) aus den Beschriftungen und Kontexttexte der 397 Abbildungen aus Artikel, die aus Open Access Journals (NOA Projekt http://noa.wp.hs-hannover.de) stammen. Die Artikel haben meist mehrere Abbildungen, die aber nicht alle mit aufgenommen wurden. Es sind 397 einzelne txt-Dateien, angezeigt werden die Datensätze 150 bis 170.

# %% [markdown]
# ### Vorkommenshäufigkeit der Terme

# %%
import glob
import nltk
import codecs
import pprint
import treetaggerwrapper


def extract_kw(datei):
    tagger = treetaggerwrapper.TreeTagger(TAGLANG='en')
    
    textfile = codecs.open(datei, "r", "utf-8")
    text = textfile.read()
    textfile.close()

    sentences = nltk.sent_tokenize(text)#Aufteilen des Datensatzes in Sätze
    sentences_tok = [nltk.word_tokenize(sent) for sent in sentences] #Aufteilen der Sätze in Wörter
    nouns = [] 
    for sent in sentences_tok:
        tags = tagger.tag_text(sent,tagonly=True) #Erstellt Liste mit: Token+Tag z.B. tag\tVV\ttag 
        tags2 = treetaggerwrapper.make_tags(tags); #Erstellt Tupel daraus z.B. Tag(word='tag', pos='VB', lemma='tag')
        nouns_from_sent = [lemma for (word,pos,lemma) in tags2 if pos == "NN" or pos == "NNS" or pos == "VB"] # Grundform von Nomen, Verb in Grundform
        nouns.extend(nouns_from_sent) #Terme werden in Liste nouns hinzugefügt
               
    fdist = nltk.FreqDist(nouns)#Anzahl Vorkommen der Terme (bestehend aus Nomen oder Verben)
    
    return fdist.most_common(15)#Anzahl der Ausgabe der Keywords pro Abbildung (Beschriftung inkl. Textreferenzen)
 

filelist = glob.glob("doi-cap-con/*.txt")#glob-Modul für Pfadnamen nach Muster
for f in filelist[150:170]: #Anzahl der Dateien 396, aufgerufen werden hier 20
    terme = extract_kw(f) #Funktion extract_term(), aufgerufen mit jeder Datei (f)
    pprint.pprint(f) #Ausgabe Name der Textdatei
    pprint.pprint(terme) #Ausgabe der Terme + Anzahl Vorkommen der Wörter
    pprint.pprint("------------------------------")
# Out:
# 'doi-cap-con/10.1155:2016:1875357.txt'
# [('stripe', 7),
#  ('slot', 6),
#  ('size', 6),
#  ('wavelength', 5),
#  ('datum', 4),
#  ('time', 4),
#  ('system', 3),
#  ('fabric', 3),
#  ('switch', 3),
#  ('bit', 3),
#  ('computer', 2),
#  ('consideration', 2),
#  ('control', 2),
#  ('switching', 2),
#  ('be', 2)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1901493.txt'
# [('ball', 4),
#  ('condition', 3),
#  ('tribotester', 3),
#  ('four-ball', 2),
#  ('lubricant', 2),
#  ('contact', 2),
#  ('kg', 2),
#  ('lubrication', 1),
#  ('place', 1),
#  ('load', 1),
#  ('spindle', 1),
#  ('engine', 1),
#  ('oil', 1),
#  ('test', 1),
#  ('geometry', 1)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1925827.txt'
# [('rectangle', 5),
#  ('distribution', 5),
#  ('space', 4),
#  ('condition', 4),
#  ('k', 4),
#  ('state', 4),
#  ('lattice', 3),
#  ('=P', 3),
#  ('range', 3),
#  ('boundary', 3),
#  ('m', 2),
#  ('transition', 2),
#  ('ρ→∞', 2),
#  ('walk', 2),
#  ('be', 2)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1928465.txt'
# [('curve', 2),
#  ('weather', 1),
#  ('hour', 1),
#  ('trigger', 1),
#  ('transient', 1),
#  ('focus', 1),
#  ('S', 1),
#  ('behaviour', 1),
#  ('light', 1),
#  ('datum', 1),
#  ('telescope', 1),
#  ('observation', 1),
#  ('end', 1)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1962438.txt'
# [('capacitance', 2),
#  ('voltage', 2),
#  ('condition', 2),
#  ('diagram', 2),
#  ('inverter', 2),
#  ('array', 1),
#  ('frame', 1),
#  ('weather', 1),
#  ('grid', 1),
#  ('dc', 1),
#  ('bus', 1),
#  ('value', 1),
#  ('ground', 1),
#  ('panel', 1),
#  ('diode', 1)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1979348.txt'
# [('case', 7),
#  ('DJD', 3),
#  ('lesion', 2),
#  ('patient', 2),
#  ('instability', 2),
#  ('18–59', 1),
#  ('diagnosis', 1),
#  ('OCD', 1),
#  ('plug', 1),
#  ('age', 1),
#  ('%', 1),
#  ('osteochondritis', 1),
#  ('ligament', 1),
#  ('tear', 1),
#  ('dissecans', 1)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2136381.txt'
# [('difference', 4),
#  ('score', 3),
#  ('follow-up', 3),
#  ('patient', 3),
#  ('pain', 3),
#  ('period', 2),
#  ('group', 2),
#  ('study', 2),
#  ('level', 2),
#  ('number', 2),
#  ('%', 2),
#  ('assessment', 2),
#  ('time', 1),
#  ('forty', 1),
#  ('treatment', 1)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2175896.txt'
# [('concentration', 3),
#  ('time', 2),
#  ('prazosin', 2),
#  ('curve', 2),
#  ('grey', 1),
#  ('metabolite', 1),
#  ('area', 1),
#  ('half-life', 1),
#  ('condition', 1),
#  ('gender', 1),
#  ('participant', 1),
#  ('kinetics', 1),
#  ('Pharmacokinetics', 1),
#  ('elimination', 1),
#  ('effect', 1)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2303181.txt'
# [('output', 7),
#  ('weight', 7),
#  ('variable', 6),
#  ('input', 6),
#  ('math', 5),
#  ('/math', 5),
#  ('\\\\mathrm', 4),
#  ('network', 4),
#  ('value', 4),
#  ('layer', 4),
#  ('y', 3),
#  ('exemplar', 3),
#  ('notation', 3),
#  ('xi', 3),
#  ('function', 3)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2315949.txt'
# [('\\\\mathrm', 3),
#  ('hydrocarbon', 3),
#  ('molecule', 3),
#  ('sheet', 2),
#  ('be', 2),
#  ('graphene', 2),
#  ('family', 2),
#  ('member', 2),
#  ('P', 1),
#  ('/math', 1),
#  ('surface', 1),
#  ('benzene', 1),
#  ('valence', 1),
#  ('piece', 1),
#  ('graphite', 1)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2350615.txt'
# [('water', 2), ('research', 1), ('location', 1)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2380540.txt'
# [('phenanthridine', 3),
#  ('drug', 3),
#  ('nitrate', 2),
#  ('platinum', 2),
#  ('complex', 2),
#  ('DNA', 2),
#  ('tumor', 2),
#  ('quinoline', 2),
#  ('line', 2),
#  ('pyridine', 2),
#  ('cell', 2),
#  ('activity', 2),
#  ('distortion', 1),
#  ('formula', 1),
#  ('response', 1)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2385429.txt'
# [('sentiment', 3),
#  ('process', 2),
#  ('word', 2),
#  ('transformation', 1),
#  ('data', 1),
#  ('datum', 1),
#  ('score', 1),
#  ('entity', 1),
#  ('insight', 1),
#  ('building', 1),
#  ('subprocesses', 1),
#  ('feedback', 1),
#  ('recognition', 1),
#  ('cloud', 1),
#  ('block', 1)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2409521.txt'
# [('fault', 5),
#  ('test', 4),
#  ('result', 3),
#  ('radix', 3),
#  ('experiment', 3),
#  ('parameter', 3),
#  ('step', 3),
#  ('input', 3),
#  ('value', 3),
#  ('case', 3),
#  ('program', 2),
#  ('show', 2),
#  ('interaction', 2),
#  ('number', 2),
#  ('canFIS', 2)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2458685.txt'
# [('phase', 13),
#  ('content', 10),
#  ('addition', 9),
#  ('hardness', 6),
#  ('sample', 6),
#  ('wt', 5),
#  ('microwave', 5),
#  ('%', 5),
#  ('pattern', 5),
#  ('θ', 4),
#  ('zirconia', 4),
#  ('temperature', 4),
#  ('time', 4),
#  ('reflection', 3),
#  ('holding', 3)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2606453.txt'
# [('resection', 8),
#  ('cradle', 8),
#  ('iPod', 5),
#  ('femur', 4),
#  ('digitalisation', 4),
#  ('handheld', 4),
#  ('landmark', 3),
#  ('system', 3),
#  ('block', 3),
#  ('surgeon', 3),
#  ('be', 3),
#  ('tibia', 3),
#  ('bone', 3),
#  ('navigation', 3),
#  ('surface', 2)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2642361.txt'
# [('sRBCs', 5),
#  ('detection', 3),
#  ('cell', 3),
#  ('bed', 3),
#  ('system', 2),
#  ('vessel', 2),
#  ('crisis', 2),
#  ('monitoring', 2),
#  ('blood', 2),
#  ('imaging', 1),
#  ('well-therapy', 1),
#  ('efficiency', 1),
#  ('diagnosis', 1),
#  ('disease', 1),
#  ('episode', 1)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2653915.txt'
# [('participant', 4),
#  ('male', 3),
#  ('year', 2),
#  ('gait', 2),
#  ('side', 2),
#  ('e', 2),
#  ('analysis', 2),
#  ('patient', 2),
#  ('female', 2),
#  ('approval', 1),
#  ('laboratory', 1),
#  ('group', 1),
#  ('test', 1),
#  ('a–i', 1),
#  ('shoe', 1)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2794364.txt'
# [('ng/mL', 10),
#  ('concentration', 7),
#  ('surgery', 7),
#  ('serum', 6),
#  ('dsDNA', 6),
#  ('median', 5),
#  ('/math', 3),
#  ('math', 3),
#  ('baseline', 3),
#  ('change', 3),
#  ('patient', 3),
#  ('group', 2),
#  ('off-pump', 2),
#  ('on-pump', 2),
#  ('cohort', 2)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2937632.txt'
# [('glass', 5),
#  ('car', 5),
#  ('participant', 4),
#  ('headband', 4),
#  ('device', 4),
#  ('experiment', 4),
#  ('projection', 3),
#  ('laboratory', 2),
#  ('coupling', 2),
#  ('screen', 2),
#  ('left', 2),
#  ('VE', 2),
#  ('simulator', 2),
#  ('environment', 2),
#  ('task', 2)]
# '------------------------------'

# %% [markdown]
# ## Termfrequenz
# Termfrequenz statt einfache Vorkommenshäufigkeit der Terme. Anzahl Termvorkommen geteilt durch die Länge des Textes (Datensatzes).

# %%
import glob
import nltk
import codecs
import pprint
import treetaggerwrapper
import math

df = {} 
tagger = treetaggerwrapper.TreeTagger(TAGLANG='en')

def substantive_zaehlen(datei): #Anzahl der Substantive in einer Datei zählen, 397 Dokumente
    textfile = codecs.open(datei, "r", "utf-8")
    text = textfile.read()
    textfile.close()
    
    nouns_in_text = [] #Liste für Häufigkeit/Anzahl von allen NN+VB in einem Text
    
    sentences = nltk.sent_tokenize(text) #Aufteilen des Textes in Sätze
    sentences_tok = [nltk.word_tokenize(sent) for sent in sentences] #Aufteilen der Sätze in Wörter
    nouns = [] 
    for sent in sentences_tok:
        tags = tagger.tag_text(sent,tagonly=True) #Erstellt Liste mit: Token+Tag z.B. tag\tVV\ttag 
        tags2 = treetaggerwrapper.make_tags(tags); #Erstellt Tupel daraus z.B. Tag(word='tag', pos='VB', lemma='tag')
        nouns_from_sent = [lemma for (word,pos,lemma) in tags2 if pos == "NN" or pos == "NNS" or pos == "VB"] #Stammform von NN und VB
        for substantiv in nouns_from_sent:
            if substantiv not in nouns_in_text: 
                nouns_in_text.append(substantiv) #Stammform der NN + VB werden der Liste nouns_in_text einmal hinzugefügt
                
    for n in nouns_in_text: #Für jedes Substantiv im Text die Häufigkeit für n
        df_n = df.get(n,0) #Erstes Argument ist der Schlüssel, das zweite Argument ist der Wert, der zurückgegeben wird, falls der Schlüssel im Dictionary nicht vorhanden ist 
        df[n] = df_n + 1 #Neuer Wert (+Schlüssel) wird dem Dictionary hinzugefügt
    

for f in glob.glob("doi-cap-con/*.txt"): #Anwenden auf alle Texte
    substantive_zaehlen(f) #Funktion substantive_zaehlen(), aufgerufen mit jeder Datei (f)
    

def extract_term(datei,nr_of_docs): #Funktion für Berechnung der inversen Dokumentfrequenz 
    tagger = treetaggerwrapper.TreeTagger(TAGLANG='en')
    
    textfile = codecs.open(datei, "r", "utf-8")
    text = textfile.read()
    textfile.close()
    
    sentences = nltk.sent_tokenize(text)#Aufteilen der Datensätze in Sätze
    sentences_tok = [nltk.word_tokenize(sent) for sent in sentences]#Aufteilen der Sätze in Wörter
    nouns = [] #Liste
    for sent in sentences_tok:
        tags = tagger.tag_text(sent,tagonly=True) #Erstellt Liste mit: Token+Tag z.B. tag\tVV\ttag 
        tags2 = treetaggerwrapper.make_tags(tags); #Erstellt Tupel daraus z.B. Tag(word='tag', pos='VB', lemma='tag')
        nouns_from_sent = [lemma for (word,pos,lemma) in tags2 if pos == "NN" or pos == "NNS" or pos == "VB"] #Grundform von NN, NNS und VB
        nouns.extend(nouns_from_sent)#Terme werden in Liste nouns hinzugefügt
    fdist = nltk.FreqDist(nouns)  #Anzahl Vorkommen der Terme
    
    for word in fdist: #Normalisierte Termfrequenz für Grundformen von NN+VB+NNS
            fdist[word] = float(fdist[word]) / float(len(nouns)) #Anzahl der Wörter durch Länge aller Wörter in einem Datensatz
        
    
    return fdist.most_common(15) #Die häufigsten 15
 
filelist = glob.glob("doi-cap-con/*.txt") #glob-Modul für Pfadnamen nach Muster
nr_of_docs = len(filelist) 
for f in filelist[150:170]: #Anzahl der Dateien 397, aufgerufen werden hier 20 
    terme = extract_term(f,nr_of_docs) #Funktion extract_term(), aufgerufen mit jeder Datei (f)
    pprint.pprint(f) #Ausgabe Name der Textdatei
    pprint.pprint(terme) #Ausgabe der Terme + Anzahl Vorkommen der Wörter (tf-idf)
    pprint.pprint("------------------------------")
# Out:
# 'doi-cap-con/10.1155:2016:1875357.txt'
# [('stripe', 0.07954545454545454),
#  ('slot', 0.06818181818181818),
#  ('size', 0.06818181818181818),
#  ('wavelength', 0.056818181818181816),
#  ('datum', 0.045454545454545456),
#  ('time', 0.045454545454545456),
#  ('system', 0.03409090909090909),
#  ('fabric', 0.03409090909090909),
#  ('switch', 0.03409090909090909),
#  ('bit', 0.03409090909090909),
#  ('computer', 0.022727272727272728),
#  ('consideration', 0.022727272727272728),
#  ('control', 0.022727272727272728),
#  ('switching', 0.022727272727272728),
#  ('be', 0.022727272727272728)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1901493.txt'
# [('ball', 0.08888888888888889),
#  ('condition', 0.06666666666666667),
#  ('tribotester', 0.06666666666666667),
#  ('four-ball', 0.044444444444444446),
#  ('lubricant', 0.044444444444444446),
#  ('contact', 0.044444444444444446),
#  ('kg', 0.044444444444444446),
#  ('lubrication', 0.022222222222222223),
#  ('place', 0.022222222222222223),
#  ('load', 0.022222222222222223),
#  ('spindle', 0.022222222222222223),
#  ('engine', 0.022222222222222223),
#  ('oil', 0.022222222222222223),
#  ('test', 0.022222222222222223),
#  ('geometry', 0.022222222222222223)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1925827.txt'
# [('rectangle', 0.05263157894736842),
#  ('distribution', 0.05263157894736842),
#  ('space', 0.042105263157894736),
#  ('condition', 0.042105263157894736),
#  ('k', 0.042105263157894736),
#  ('state', 0.042105263157894736),
#  ('lattice', 0.031578947368421054),
#  ('=P', 0.031578947368421054),
#  ('range', 0.031578947368421054),
#  ('boundary', 0.031578947368421054),
#  ('m', 0.021052631578947368),
#  ('transition', 0.021052631578947368),
#  ('ρ→∞', 0.021052631578947368),
#  ('walk', 0.021052631578947368),
#  ('be', 0.021052631578947368)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1928465.txt'
# [('curve', 0.14285714285714285),
#  ('weather', 0.07142857142857142),
#  ('hour', 0.07142857142857142),
#  ('trigger', 0.07142857142857142),
#  ('transient', 0.07142857142857142),
#  ('focus', 0.07142857142857142),
#  ('S', 0.07142857142857142),
#  ('behaviour', 0.07142857142857142),
#  ('light', 0.07142857142857142),
#  ('datum', 0.07142857142857142),
#  ('telescope', 0.07142857142857142),
#  ('observation', 0.07142857142857142),
#  ('end', 0.07142857142857142)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1962438.txt'
# [('capacitance', 0.07407407407407407),
#  ('voltage', 0.07407407407407407),
#  ('condition', 0.07407407407407407),
#  ('diagram', 0.07407407407407407),
#  ('inverter', 0.07407407407407407),
#  ('array', 0.037037037037037035),
#  ('frame', 0.037037037037037035),
#  ('weather', 0.037037037037037035),
#  ('grid', 0.037037037037037035),
#  ('dc', 0.037037037037037035),
#  ('bus', 0.037037037037037035),
#  ('value', 0.037037037037037035),
#  ('ground', 0.037037037037037035),
#  ('panel', 0.037037037037037035),
#  ('diode', 0.037037037037037035)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1979348.txt'
# [('case', 0.23333333333333334),
#  ('DJD', 0.1),
#  ('lesion', 0.06666666666666667),
#  ('patient', 0.06666666666666667),
#  ('instability', 0.06666666666666667),
#  ('18–59', 0.03333333333333333),
#  ('diagnosis', 0.03333333333333333),
#  ('OCD', 0.03333333333333333),
#  ('plug', 0.03333333333333333),
#  ('age', 0.03333333333333333),
#  ('%', 0.03333333333333333),
#  ('osteochondritis', 0.03333333333333333),
#  ('ligament', 0.03333333333333333),
#  ('tear', 0.03333333333333333),
#  ('dissecans', 0.03333333333333333)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2136381.txt'
# [('difference', 0.07692307692307693),
#  ('score', 0.057692307692307696),
#  ('follow-up', 0.057692307692307696),
#  ('patient', 0.057692307692307696),
#  ('pain', 0.057692307692307696),
#  ('period', 0.038461538461538464),
#  ('group', 0.038461538461538464),
#  ('study', 0.038461538461538464),
#  ('level', 0.038461538461538464),
#  ('number', 0.038461538461538464),
#  ('%', 0.038461538461538464),
#  ('assessment', 0.038461538461538464),
#  ('time', 0.019230769230769232),
#  ('forty', 0.019230769230769232),
#  ('treatment', 0.019230769230769232)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2175896.txt'
# [('concentration', 0.14285714285714285),
#  ('time', 0.09523809523809523),
#  ('prazosin', 0.09523809523809523),
#  ('curve', 0.09523809523809523),
#  ('grey', 0.047619047619047616),
#  ('metabolite', 0.047619047619047616),
#  ('area', 0.047619047619047616),
#  ('half-life', 0.047619047619047616),
#  ('condition', 0.047619047619047616),
#  ('gender', 0.047619047619047616),
#  ('participant', 0.047619047619047616),
#  ('kinetics', 0.047619047619047616),
#  ('Pharmacokinetics', 0.047619047619047616),
#  ('elimination', 0.047619047619047616),
#  ('effect', 0.047619047619047616)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2303181.txt'
# [('output', 0.046357615894039736),
#  ('weight', 0.046357615894039736),
#  ('variable', 0.039735099337748346),
#  ('input', 0.039735099337748346),
#  ('math', 0.033112582781456956),
#  ('/math', 0.033112582781456956),
#  ('\\\\mathrm', 0.026490066225165563),
#  ('network', 0.026490066225165563),
#  ('value', 0.026490066225165563),
#  ('layer', 0.026490066225165563),
#  ('y', 0.019867549668874173),
#  ('exemplar', 0.019867549668874173),
#  ('notation', 0.019867549668874173),
#  ('xi', 0.019867549668874173),
#  ('function', 0.019867549668874173)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2315949.txt'
# [('\\\\mathrm', 0.08571428571428572),
#  ('hydrocarbon', 0.08571428571428572),
#  ('molecule', 0.08571428571428572),
#  ('sheet', 0.05714285714285714),
#  ('be', 0.05714285714285714),
#  ('graphene', 0.05714285714285714),
#  ('family', 0.05714285714285714),
#  ('member', 0.05714285714285714),
#  ('P', 0.02857142857142857),
#  ('/math', 0.02857142857142857),
#  ('surface', 0.02857142857142857),
#  ('benzene', 0.02857142857142857),
#  ('valence', 0.02857142857142857),
#  ('piece', 0.02857142857142857),
#  ('graphite', 0.02857142857142857)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2350615.txt'
# [('water', 0.5), ('research', 0.25), ('location', 0.25)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2380540.txt'
# [('phenanthridine', 0.04918032786885246),
#  ('drug', 0.04918032786885246),
#  ('nitrate', 0.03278688524590164),
#  ('platinum', 0.03278688524590164),
#  ('complex', 0.03278688524590164),
#  ('DNA', 0.03278688524590164),
#  ('tumor', 0.03278688524590164),
#  ('quinoline', 0.03278688524590164),
#  ('line', 0.03278688524590164),
#  ('pyridine', 0.03278688524590164),
#  ('cell', 0.03278688524590164),
#  ('activity', 0.03278688524590164),
#  ('distortion', 0.01639344262295082),
#  ('formula', 0.01639344262295082),
#  ('response', 0.01639344262295082)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2385429.txt'
# [('sentiment', 0.11538461538461539),
#  ('process', 0.07692307692307693),
#  ('word', 0.07692307692307693),
#  ('transformation', 0.038461538461538464),
#  ('data', 0.038461538461538464),
#  ('datum', 0.038461538461538464),
#  ('score', 0.038461538461538464),
#  ('entity', 0.038461538461538464),
#  ('insight', 0.038461538461538464),
#  ('building', 0.038461538461538464),
#  ('subprocesses', 0.038461538461538464),
#  ('feedback', 0.038461538461538464),
#  ('recognition', 0.038461538461538464),
#  ('cloud', 0.038461538461538464),
#  ('block', 0.038461538461538464)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2409521.txt'
# [('fault', 0.0847457627118644),
#  ('test', 0.06779661016949153),
#  ('result', 0.05084745762711865),
#  ('radix', 0.05084745762711865),
#  ('experiment', 0.05084745762711865),
#  ('parameter', 0.05084745762711865),
#  ('step', 0.05084745762711865),
#  ('input', 0.05084745762711865),
#  ('value', 0.05084745762711865),
#  ('case', 0.05084745762711865),
#  ('program', 0.03389830508474576),
#  ('show', 0.03389830508474576),
#  ('interaction', 0.03389830508474576),
#  ('number', 0.03389830508474576),
#  ('canFIS', 0.03389830508474576)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2458685.txt'
# [('phase', 0.08843537414965986),
#  ('content', 0.06802721088435375),
#  ('addition', 0.061224489795918366),
#  ('hardness', 0.04081632653061224),
#  ('sample', 0.04081632653061224),
#  ('wt', 0.034013605442176874),
#  ('microwave', 0.034013605442176874),
#  ('%', 0.034013605442176874),
#  ('pattern', 0.034013605442176874),
#  ('θ', 0.027210884353741496),
#  ('zirconia', 0.027210884353741496),
#  ('temperature', 0.027210884353741496),
#  ('time', 0.027210884353741496),
#  ('reflection', 0.02040816326530612),
#  ('holding', 0.02040816326530612)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2606453.txt'
# [('resection', 0.058823529411764705),
#  ('cradle', 0.058823529411764705),
#  ('iPod', 0.03676470588235294),
#  ('femur', 0.029411764705882353),
#  ('digitalisation', 0.029411764705882353),
#  ('handheld', 0.029411764705882353),
#  ('landmark', 0.022058823529411766),
#  ('system', 0.022058823529411766),
#  ('block', 0.022058823529411766),
#  ('surgeon', 0.022058823529411766),
#  ('be', 0.022058823529411766),
#  ('tibia', 0.022058823529411766),
#  ('bone', 0.022058823529411766),
#  ('navigation', 0.022058823529411766),
#  ('surface', 0.014705882352941176)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2642361.txt'
# [('sRBCs', 0.0847457627118644),
#  ('detection', 0.05084745762711865),
#  ('cell', 0.05084745762711865),
#  ('bed', 0.05084745762711865),
#  ('system', 0.03389830508474576),
#  ('vessel', 0.03389830508474576),
#  ('crisis', 0.03389830508474576),
#  ('monitoring', 0.03389830508474576),
#  ('blood', 0.03389830508474576),
#  ('imaging', 0.01694915254237288),
#  ('well-therapy', 0.01694915254237288),
#  ('efficiency', 0.01694915254237288),
#  ('diagnosis', 0.01694915254237288),
#  ('disease', 0.01694915254237288),
#  ('episode', 0.01694915254237288)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2653915.txt'
# [('participant', 0.09523809523809523),
#  ('male', 0.07142857142857142),
#  ('year', 0.047619047619047616),
#  ('gait', 0.047619047619047616),
#  ('side', 0.047619047619047616),
#  ('e', 0.047619047619047616),
#  ('analysis', 0.047619047619047616),
#  ('patient', 0.047619047619047616),
#  ('female', 0.047619047619047616),
#  ('approval', 0.023809523809523808),
#  ('laboratory', 0.023809523809523808),
#  ('group', 0.023809523809523808),
#  ('test', 0.023809523809523808),
#  ('a–i', 0.023809523809523808),
#  ('shoe', 0.023809523809523808)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2794364.txt'
# [('ng/mL', 0.1282051282051282),
#  ('concentration', 0.08974358974358974),
#  ('surgery', 0.08974358974358974),
#  ('serum', 0.07692307692307693),
#  ('dsDNA', 0.07692307692307693),
#  ('median', 0.0641025641025641),
#  ('/math', 0.038461538461538464),
#  ('math', 0.038461538461538464),
#  ('baseline', 0.038461538461538464),
#  ('change', 0.038461538461538464),
#  ('patient', 0.038461538461538464),
#  ('group', 0.02564102564102564),
#  ('off-pump', 0.02564102564102564),
#  ('on-pump', 0.02564102564102564),
#  ('cohort', 0.02564102564102564)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2937632.txt'
# [('glass', 0.05263157894736842),
#  ('car', 0.05263157894736842),
#  ('participant', 0.042105263157894736),
#  ('headband', 0.042105263157894736),
#  ('device', 0.042105263157894736),
#  ('experiment', 0.042105263157894736),
#  ('projection', 0.031578947368421054),
#  ('laboratory', 0.021052631578947368),
#  ('coupling', 0.021052631578947368),
#  ('screen', 0.021052631578947368),
#  ('left', 0.021052631578947368),
#  ('VE', 0.021052631578947368),
#  ('simulator', 0.021052631578947368),
#  ('environment', 0.021052631578947368),
#  ('task', 0.021052631578947368)]
# '------------------------------'

# %% [markdown]
# ### Inverse Dokumenthäufigkeit:
# (en: inverse Document Frequency (IDF))
# Tf-idf-Werte Berechnung für Substantive+Verben
# Terme der Datensätze: Wortformen NN, NNS und VB in ihrer Grundform

# %%
import glob
import nltk
import codecs
import pprint
import treetaggerwrapper
import math

df = {} 
tagger = treetaggerwrapper.TreeTagger(TAGLANG='en')

def substantive_zaehlen(datei): #Anzahl der Substantive in einer Datei zählen, 397 Dokumente
    textfile = codecs.open(datei, "r", "utf-8")
    text = textfile.read()
    textfile.close()
    
    nouns_in_text = [] #Liste für Häufigkeit/Anzahl von allen NN+NNS+VB in einem Text
    
    sentences = nltk.sent_tokenize(text) #Aufteilen des Textes in Sätze
    sentences_tok = [nltk.word_tokenize(sent) for sent in sentences] #Aufteilen der Sätze in Wörter
    nouns = [] 
    for sent in sentences_tok:
        tags = tagger.tag_text(sent,tagonly=True) #Erstellt Liste mit: Token+Tag z.B. tag\tVV\ttag 
        tags2 = treetaggerwrapper.make_tags(tags); #Erstellt Tupel daraus z.B. Tag(word='tag', pos='VB', lemma='tag')
        nouns_from_sent = [lemma for (word,pos,lemma) in tags2 if pos == "NN" or pos == "NNS" or pos == "VB"] #Stammform von NN, NNS und VB
        for substantiv in nouns_from_sent:
            if substantiv not in nouns_in_text: 
                nouns_in_text.append(substantiv) #Stammform der NN, NNS + VB werden der Liste nouns_in_text einmal hinzugefügt
                
    for n in nouns_in_text: #Für jedes Substantiv im Text die Häufigkeit für n 
        df_n = df.get(n,0) #Erstes Argument ist der Schlüssel, das zweite Argument ist der Wert, der zurückgegeben wird, falls der Schlüssel im Dictionary nicht vorhanden ist 
        df[n] = df_n + 1 #Neuer Wert (+Schlüssel) wird dem Dictionary hinzugefügt
    

for f in glob.glob("doi-cap-con/*.txt"): #Anwenden auf alle Texte
    substantive_zaehlen(f) #Funktion substantive_zaehlen(), aufgerufen mit jeder Datei (f)
    

def extract_term(datei,nr_of_docs): #Funktion für Berechnung der inversen Dokumentfrequenz (idf)
    tagger = treetaggerwrapper.TreeTagger(TAGLANG='en')
    
    textfile = codecs.open(datei, "r", "utf-8")
    text = textfile.read()
    textfile.close()
    
    sentences = nltk.sent_tokenize(text)#Aufteilen der Datensätze in Sätze
    sentences_tok = [nltk.word_tokenize(sent) for sent in sentences]#Aufteilen der Sätze in Wörter
    nouns = [] 
    for sent in sentences_tok:
        tags = tagger.tag_text(sent,tagonly=True) #Erstellt Liste mit: Token+Tag z.B. tag\tVV\ttag 
        tags2 = treetaggerwrapper.make_tags(tags); #Erstellt Tupel daraus z.B. Tag(word='tag', pos='VB', lemma='tag')
        nouns_from_sent = [lemma for (word,pos,lemma) in tags2 if pos == "NN" or pos == "NNS" or pos == "VB"] #Grundform von NN, NNS und VB 
        nouns.extend(nouns_from_sent)#Terme werden in Liste nouns hinzugefügt
    fdist = nltk.FreqDist(nouns)  #Anzahl Vorkommen der Terme
    
    for word in fdist: #Tf-idf-Maß Berechnung für alle Grundformen von NN+NNS+VB
        idf = 1.0 + math.log(float(nr_of_docs) / float(df[word])) #Log von (Anzahl Dokumente dividiert durch Wort+Schlüssel)
        fdist[word] = float(fdist[word]) / float(len(nouns)) * idf #Anzahl der Wörter durch Länge aller Wörter mulipliziert mit idf (s.o.) 
 
    
    return fdist.most_common(15) #Die häufigsten 15
 
filelist = glob.glob("doi-cap-con/*.txt") #glob-Modul für Pfadnamen nach Muster
nr_of_docs = len(filelist) #Länge der Dateiliste
for f in filelist[150:170]: #Anzahl der Dateien 397, aufgerufen werden hier 20 
    terme = extract_term(f,nr_of_docs) #Funktion extract_term() aufgerufen mit jeder Datei (f)
    pprint.pprint(f) #Ausgabe Name der Textdatei
    pprint.pprint(terme) #Ausgabe der Terme + Anzahl Vorkommen der Wörter (tf-idf)
    pprint.pprint("------------------------------")
# Out:
# 'doi-cap-con/10.1155:2016:1875357.txt'
# [('stripe', 0.5553397668043337),
#  ('slot', 0.4760055144037145),
#  ('wavelength', 0.3179045369394653),
#  ('fabric', 0.23800275720185726),
#  ('bit', 0.23800275720185726),
#  ('size', 0.2092766731245228),
#  ('switch', 0.17692004802362812),
#  ('switching', 0.14291515978851216),
#  ('computer', 0.12716181477578614),
#  ('conversion', 0.12716181477578614),
#  ('time', 0.11330808370556096),
#  ('advantage', 0.11140846976306013),
#  ('datum', 0.10579335732258896),
#  ('system', 0.1026518965125804),
#  ('consideration', 0.10219335366969272)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1901493.txt'
# [('ball', 0.5229157264521218),
#  ('tribotester', 0.46542761408363204),
#  ('four-ball', 0.3102850760557547),
#  ('lubricant', 0.3102850760557547),
#  ('kg', 0.23065132186784112),
#  ('condition', 0.22119017100832228),
#  ('contact', 0.20794796081157488),
#  ('lubrication', 0.15514253802787736),
#  ('combustion', 0.15514253802787736),
#  ('follower', 0.15514253802787736),
#  ('three-point', 0.15514253802787736),
#  ('90°C', 0.15514253802787736),
#  ('cam', 0.15514253802787736),
#  ('friction', 0.13973926734876746),
#  ('rpm', 0.13973926734876746)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1925827.txt'
# [('rectangle', 0.26502652958942985),
#  ('=P', 0.22046571193435202),
#  ('k', 0.20143956353340048),
#  ('lattice', 0.1766879952674081),
#  ('space', 0.16781818685054692),
#  ('state', 0.16193347348738235),
#  ('distribution', 0.15749632445737927),
#  ('ρ→∞', 0.14697714128956801),
#  ('walk', 0.14697714128956801),
#  ('0⩽r⩽R-1', 0.14697714128956801),
#  ('r=0', 0.14697714128956801),
#  ('condition', 0.13969905537367722),
#  ('boundary', 0.13099581685889256),
#  ('r', 0.11309423786990273),
#  ('balance', 0.10925588930581948)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1928465.txt'
# [('curve', 0.5433371972723621),
#  ('trigger', 0.4986724436610343),
#  ('telescope', 0.4986724436610343),
#  ('transient', 0.4491619307638953),
#  ('weather', 0.3837125927728843),
#  ('hour', 0.34172783099416154),
#  ('focus', 0.34172783099416154),
#  ('behaviour', 0.3342020798757453),
#  ('light', 0.31016834868851584),
#  ('S', 0.30063039207247855),
#  ('end', 0.24892190355628574),
#  ('observation', 0.22837318409544424),
#  ('datum', 0.16624670436406835)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1962438.txt'
# [('capacitance', 0.46579755782922483),
#  ('inverter', 0.46579755782922483),
#  ('voltage', 0.3543844173272786),
#  ('diagram', 0.27870654713972437),
#  ('dc', 0.2585708967131289),
#  ('inductor', 0.2585708967131289),
#  ('nF/kW', 0.2585708967131289),
#  ('condition', 0.24576685667591364),
#  ('bus', 0.21788155268838408),
#  ('diode', 0.21788155268838408),
#  ('weather', 0.19896208514149555),
#  ('switch', 0.19220943488986758),
#  ('array', 0.186500150451821),
#  ('frame', 0.1771922086636393),
#  ('humidity', 0.1771922086636393)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1979348.txt'
# [('DJD', 0.6981414211254481),
#  ('case', 0.681559946831881),
#  ('instability', 0.39218679483909136),
#  ('lesion', 0.326798177971643),
#  ('18–59', 0.23271380704181602),
#  ('OCD', 0.23271380704181602),
#  ('plug', 0.23271380704181602),
#  ('osteochondritis', 0.23271380704181602),
#  ('tear', 0.23271380704181602),
#  ('dissecans', 0.23271380704181602),
#  ('oat', 0.23271380704181602),
#  ('patient', 0.2284044099843378),
#  ('ligament', 0.18650399500448633),
#  ('inclusion', 0.1633990889858215),
#  ('diagnosis', 0.15278396461520366)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2136381.txt'
# [('follow-up', 0.33939241861075214),
#  ('pain', 0.3227953759693033),
#  ('score', 0.23602168000144133),
#  ('difference', 0.2246900923621586),
#  ('patient', 0.1976576624864462),
#  ('assessment', 0.15954618719993324),
#  ('forty', 0.13425796560104772),
#  ('pathology', 0.13425796560104772),
#  ('T-group', 0.13425796560104772),
#  ('between-group', 0.13425796560104772),
#  ('intergroup', 0.13425796560104772),
#  ('resp', 0.13425796560104772),
#  ('pretreatment', 0.12092821212874107),
#  ('period', 0.11369471232766659),
#  ('efficacy', 0.11313080620358405)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2175896.txt'
# [('prazosin', 0.6648965915480457),
#  ('concentration', 0.42749002352717225),
#  ('curve', 0.3622247981815747),
#  ('Pharmacokinetics', 0.33244829577402285),
#  ('elimination', 0.33244829577402285),
#  ('half-life', 0.2994412871759302),
#  ('kinetics', 0.2994412871759302),
#  ('pretreatment', 0.2994412871759302),
#  ('gender', 0.28013342488506526),
#  ('metabolite', 0.23978590772376984),
#  ('time', 0.23740741347831817),
#  ('grey', 0.21411940768887996),
#  ('participant', 0.20349352429296527),
#  ('condition', 0.15799297929165876),
#  ('effect', 0.12879752820182977)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2303181.txt'
# [('weight', 0.21689936309816585),
#  ('output', 0.20473678130165962),
#  ('variable', 0.17254398205188962),
#  ('input', 0.1528180130592847),
#  ('exemplar', 0.1387035936010824),
#  ('xi', 0.1387035936010824),
#  ('y', 0.1168768593891332),
#  ('notation', 0.1168768593891332),
#  ('predictor', 0.1168768593891332),
#  ('network', 0.10305620550718317),
#  ('layer', 0.10075126836838502),
#  ('backpropagation', 0.0924690624007216),
#  ('math', 0.08607243631061587),
#  ('/math', 0.08607243631061587),
#  ('\\\\mathrm', 0.08530368465062035)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2315949.txt'
# [('hydrocarbon', 0.5389943169166744),
#  ('molecule', 0.36628834372733754),
#  ('graphene', 0.35932954461111627),
#  ('sheet', 0.29655169954436716),
#  ('\\\\mathrm', 0.2760183510480787),
#  ('family', 0.25236942021673964),
#  ('member', 0.25236942021673964),
#  ('graphite', 0.19946897746441372),
#  ('benzene', 0.17966477230555813),
#  ('valence', 0.16808005493103914),
#  ('utilization', 0.15986056714670255),
#  ('bond', 0.14827584977218358),
#  ('piece', 0.14005636198784702),
#  ('k', 0.13669113239766462),
#  ('cycle', 0.11852002477709327)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2350615.txt'
# [('water', 1.7424533248940002),
#  ('research', 1.037050216799566),
#  ('location', 0.7623971446325387)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2380540.txt'
# [('phenanthridine', 0.3433482398977613),
#  ('platinum', 0.22889882659850758),
#  ('quinoline', 0.22889882659850758),
#  ('pyridine', 0.22889882659850758),
#  ('drug', 0.22541896418636606),
#  ('nitrate', 0.17613037045312724),
#  ('tumor', 0.16072041539589002),
#  ('DNA', 0.15340423338558803),
#  ('complex', 0.144802126353867),
#  ('activity', 0.1163090821891585),
#  ('cis', 0.11444941329925379),
#  ('oxaliplatin', 0.11444941329925379),
#  ('antitumor', 0.11444941329925379),
#  ('3-DS', 0.11444941329925379),
#  ('meantime', 0.11444941329925379)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2385429.txt'
# [('sentiment', 0.8055477936062863),
#  ('word', 0.3770748207365112),
#  ('subprocesses', 0.26851593120209544),
#  ('students’', 0.26851593120209544),
#  ('gathering', 0.26851593120209544),
#  ('preprocessing', 0.26851593120209544),
#  ('process', 0.22877546354015457),
#  ('entity', 0.2262616124071681),
#  ('insight', 0.2066144730315531),
#  ('visualization', 0.2066144730315531),
#  ('building', 0.19960210546255483),
#  ('recognition', 0.19960210546255483),
#  ('transformation', 0.1885374103682556),
#  ('feedback', 0.1885374103682556),
#  ('name', 0.18400729361224083)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2409521.txt'
# [('fault', 0.5329039856520792),
#  ('radix', 0.35498716328412616),
#  ('test', 0.23835107175964435),
#  ('canFIS', 0.2366581088560841),
#  ('input', 0.19555525399959311),
#  ('step', 0.19131551117218373),
#  ('experiment', 0.18376873125091558),
#  ('parameter', 0.17138116772594525),
#  ('case', 0.14852395935803703),
#  ('program', 0.14061697854909372),
#  ('interaction', 0.12892747053920456),
#  ('result', 0.12790708945423204),
#  ('value', 0.1267514156706275),
#  ('interactions’', 0.11832905442804205),
#  ('show', 0.10543095594395219)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2458685.txt'
# [('phase', 0.3259354114847073),
#  ('content', 0.2953984273223961),
#  ('hardness', 0.2849556820920196),
#  ('microwave', 0.23746306841001638),
#  ('wt', 0.21388663369709304),
#  ('addition', 0.21336163161967348),
#  ('zirconia', 0.17110930695767443),
#  ('θ', 0.15224815918733578),
#  ('ceramic', 0.1424778410460098),
#  ('holding', 0.12833198021825581),
#  ('sample', 0.1278068003895682),
#  ('reflection', 0.12005718209359939),
#  ('diffraction', 0.10963216936368121),
#  ('pattern', 0.10798475243143406),
#  ('cross-indentation', 0.09498522736400654)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2606453.txt'
# [('resection', 0.41067142419144004),
#  ('cradle', 0.3698980606290903),
#  ('iPod', 0.25666964011965004),
#  ('digitalisation', 0.20533571209572002),
#  ('handheld', 0.20533571209572002),
#  ('femur', 0.17302358595842265),
#  ('landmark', 0.15400178407179002),
#  ('tibia', 0.13871177273590887),
#  ('navigation', 0.13871177273590887),
#  ('surgeon', 0.12342176140002772),
#  ('bone', 0.11849947717986133),
#  ('coronal', 0.10266785604786001),
#  ('block', 0.10110703540712007),
#  ('pointer', 0.09247451515727258),
#  ('cut', 0.09247451515727258)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2642361.txt'
# [('sRBCs', 0.5916452721402102),
#  ('bed', 0.35498716328412616),
#  ('detection', 0.22456600951489544),
#  ('crisis', 0.2131615942608317),
#  ('vessel', 0.18966507966557933),
#  ('monitoring', 0.16217591979383938),
#  ('blood', 0.15860437689018422),
#  ('cell', 0.15215746600119692),
#  ('well-therapy', 0.11832905442804205),
#  ('nRBC', 0.11832905442804205),
#  ('transfusion', 0.11832905442804205),
#  ('nRBCs', 0.11832905442804205),
#  ('warning', 0.11832905442804205),
#  ('sRBC', 0.11832905442804205),
#  ('prevention', 0.10658079713041585)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2653915.txt'
# [('participant', 0.40698704858593054),
#  ('gait', 0.33244829577402285),
#  ('male', 0.32117911153331996),
#  ('female', 0.22280138658383022),
#  ('e', 0.19753337462848877),
#  ('side', 0.17550368310715006),
#  ('approval', 0.16622414788701143),
#  ('a–i', 0.16622414788701143),
#  ('shoe', 0.16622414788701143),
#  ('walker', 0.16622414788701143),
#  ('patient', 0.16314600713166985),
#  ('year', 0.15224878939696282),
#  ('stroke', 0.1497206435879651),
#  ('rehabilitation', 0.1497206435879651),
#  ('consent', 0.1332171392889188)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2794364.txt'
# [('ng/mL', 0.8950531040069846),
#  ('dsDNA', 0.5370318624041909),
#  ('surgery', 0.502126140396694),
#  ('serum', 0.3873464663230129),
#  ('median', 0.322788721935844),
#  ('concentration', 0.26855142503630053),
#  ('baseline', 0.1799549660869398),
#  ('off-pump', 0.17901062080139693),
#  ('on-pump', 0.17901062080139693),
#  ('patient', 0.13177177499096412),
#  ('cohort', 0.12911548877433762),
#  ('change', 0.11654501894896359),
#  ('/math', 0.09997644525309997),
#  ('math', 0.09997644525309997),
#  ('p', 0.09861333321347002)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2937632.txt'
# [('car', 0.3309614226681334),
#  ('headband', 0.29395428257913603),
#  ('glass', 0.27313972326454866),
#  ('device', 0.18283607922691458),
#  ('participant', 0.17993111621693772),
#  ('projection', 0.1638838339587292),
#  ('experiment', 0.15217340552707395),
#  ('VE', 0.14697714128956801),
#  ('simulator', 0.14697714128956801),
#  ('sickness', 0.14697714128956801),
#  ('screen', 0.11779199684493873),
#  ('task', 0.10925588930581948),
#  ('room', 0.10071978176670024),
#  ('coupling', 0.0985016656475881),
#  ('user', 0.0985016656475881)]
# '------------------------------'

# %% [markdown]
# # Mapping mit Wikipedia Artikel Titel
# Tf-idf Berechnung der Terme. Abgleich der Terme mit Wikipedia Artikel-Titeln, Rückgabe der Kategorien der Artikel

# %%
import glob
import nltk
import codecs
import pprint
import treetaggerwrapper
import math
import requests
from nltk.corpus import stopwords 

filelist = glob.glob("doi-cap-con/*.txt") #glob-Modul für Pfadnamen nach Muster
nr_of_docs = len(filelist) #Länge der Dateiliste
noun2cat = {} #Dictionary für Substantiv -> [Wikicats]
catStoplist = stopwords.words('categories') #Kategorien-Stoppliste (z.B Numbers)
df = {} 
tagger = treetaggerwrapper.TreeTagger(TAGLANG='en')

def substantive_zaehlen(datei): #Anzahl der Substantive in einer Datei zählen, 397 Dokumente
    textfile = codecs.open(datei, "r", "utf-8")
    text = textfile.read()
    textfile.close()
    
    nouns_in_text = [] #Liste für Häufigkeit/Anzahl von allen NN+NNS+VB in einem Text
    
    sentences = nltk.sent_tokenize(text) #Aufteilen des Textes in Sätze
    sentences_tok = [nltk.word_tokenize(sent) for sent in sentences] #Aufteilen der Sätze in Wörter
    nouns = [] 
    for sent in sentences_tok:
        tags = tagger.tag_text(sent,tagonly=True) #Erstellt Liste mit: Token+Tag z.B. tag\tVV\ttag 
        tags2 = treetaggerwrapper.make_tags(tags); #Erstellt Tupel daraus z.B. Tag(word='tag', pos='VB', lemma='tag')
        nouns_from_sent = [lemma for (word,pos,lemma) in tags2 if pos == "NN" or pos == "NNS" or pos == "VB"] #Stammform von NN, NNS und VB
        for substantiv in nouns_from_sent:
            if substantiv not in nouns_in_text: 
                nouns_in_text.append(substantiv) #Stammform der NN + VB werden der Liste nouns_in_text einmal hinzugefügt
                
    for n in nouns_in_text: #Für jedes Substantiv im Text hole die Häufigkeit für n raus
        df_n = df.get(n,0) #Erstes Argument ist der Schlüssel, das zweite Argument ist der Wert, der zurückgegeben wird, falls der Schlüssel im Dictionary nicht vorhanden ist 
        df[n] = df_n + 1 #Neuer Wert (+Schlüssel) wird dem Dictionary hinzugefügt

for f in glob.glob("doi-cap-con/*.txt"): #Anwenden auf alle Texte
    substantive_zaehlen(f) #Funktion substantive_zaehlen oben, aufgerufen mit jeder Datei (f)

    
def extract_term(datei,nr_of_docs): #Funktion für Berechnung der inversen Dokumentfrequenz 
    tagger = treetaggerwrapper.TreeTagger(TAGLANG='en')
    
    textfile = codecs.open(datei, "r", "utf8")
    text = textfile.read()
    textfile.close()
    
    sentences = nltk.sent_tokenize(text)#Aufteilen des Textes in Sätze
    sentences_tok = [nltk.word_tokenize(sent) for sent in sentences]#Aufteilen der Sätze in Wörter
    nouns = [] 
    for sent in sentences_tok:
        tags = tagger.tag_text(sent,tagonly=True) #Erstellt Liste mit: Token+Tag z.B. tag\tVV\ttag 
        tags2 = treetaggerwrapper.make_tags(tags); #Erstellt Tupel daraus z.B. Tag(word='tag', pos='VB', lemma='tag')
        nouns_from_sent = [lemma for (word,pos,lemma) in tags2 if pos == "NN" or pos == "NNS" or pos == "VB"] #Grundform von NN und VB
        nouns.extend(nouns_from_sent)#Terme werden in Liste nouns hinzugefügt
    fdist = nltk.FreqDist(nouns)  #Anzahl Vorkommen der Terme
    
    for word in fdist: #Tf-idf-Maß Berechnung für alle Grundformen von NN+NNS+VB
        idf = 1.0 + math.log(float(nr_of_docs) / float(df[word])) #Log von (Anzahl Dokumente dividiert durch Wort+Schlüssel)
        fdist[word] = float(fdist[word]) / float(len(nouns)) * idf #Anzahl der Wörter durch Länge aller Wörter mulipliziert mit idf (s.o.)        
    
    return fdist.most_common(15) #Die besten 5/10/15 Terme

def wiki_cats(term):
    cats = []
    
    response = requests.get(
        'https://en.wikipedia.org/w/api.php',
        params={
            'action': 'query',
            'format': 'json',
            'titles': term,
            'prop': 'categories',
            'clshow':'!hidden',
            'cllimit':'50'
        }
    ).json() 
    
    for pageid in  response['query']['pages']:
        if len(term) >2 :   #Terme sollen eine Länge von über 2 Buchstaben haben 
            if 'categories' in response['query']['pages'][pageid]:
                cats.extend([cat['title'] for cat in response['query']['pages'][pageid]['categories'] if cat['ns'] == 14 and not cat['title'].startswith('Category:Disambiguation') and cat['title'] not in catStoplist])

    return set(cats) #Mit set werden Duplikate entfernt

def collect_nouns(flist):
    global noun2cat
    for f in flist:
        nouns = extract_term(f, nr_of_docs)
        for (n,f) in nouns:
            noun2cat[n] = wiki_cats(n)
 

collect_nouns(filelist[150:170])


for f in filelist[150:170]: #Anzahl der Dateien 397, aufgerufen werden hier 20 
    terme = extract_term(f,nr_of_docs) #Funktion extract_term oben, aufgerufen mit jeder Datei (f)
    cats = set([c for (kw,f) in terme for c in noun2cat.get(kw)]) 
    pprint.pprint(f) 
    pprint.pprint(cats)
    pprint.pprint("------------------------------")
# Out:
# 'doi-cap-con/10.1155:2016:1875357.txt'
# {'Category:1990s fads and trends',
#  'Category:2000s fads and trends',
#  'Category:Binary arithmetic',
#  'Category:Computers',
#  'Category:Concepts in metaphysics',
#  'Category:Concepts in physics',
#  'Category:Consumer electronics',
#  'Category:Contract law',
#  'Category:Data types',
#  'Category:Electrical components',
#  'Category:Human–machine interaction',
#  'Category:Legal doctrines and principles',
#  'Category:Physical quantities',
#  'Category:Primitive types',
#  'Category:SI base quantities',
#  'Category:Size',
#  'Category:Switches',
#  'Category:Systems',
#  'Category:Units of information',
#  'Category:Waves'}
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1901493.txt'
# {'Category:Balls',
#  'Category:Classical mechanics',
#  'Category:Combustion',
#  'Category:Force',
#  'Category:Friction',
#  'Category:Lubricants',
#  'Category:Lubrication',
#  'Category:Mechanical engineering',
#  'Category:Petroleum products',
#  'Category:Tribology'}
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1925827.txt'
# {'Category:Elementary shapes',
#  'Category:Geometry',
#  'Category:Quadrilaterals',
#  'Category:Space',
#  'Category:Topology'}
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1928465.txt'
# {'Category:17th-century introductions',
#  'Category:Aptitude',
#  'Category:Assumption',
#  'Category:Astronomical imaging',
#  'Category:Astronomical instruments',
#  'Category:Cognition',
#  'Category:Curves',
#  'Category:Dutch inventions',
#  'Category:Epistemology of science',
#  'Category:Experiments',
#  'Category:General topology',
#  'Category:Light',
#  'Category:Metric geometry',
#  'Category:Observation',
#  'Category:Orders of magnitude (time)',
#  'Category:Perception',
#  'Category:Philosophy of science',
#  'Category:Radiation',
#  'Category:Science and technology in the Dutch Republic',
#  'Category:Scientific method',
#  'Category:Sources of knowledge',
#  'Category:Telescopes',
#  'Category:Topology',
#  'Category:Weather'}
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1962438.txt'
# {'Category:1904 introductions',
#  'Category:Atmospheric thermodynamics',
#  'Category:Bus transport',
#  'Category:Buses',
#  'Category:Capacitance',
#  'Category:Climate',
#  'Category:Concepts in physics',
#  'Category:Diagrams',
#  'Category:Diodes',
#  'Category:Electrical components',
#  'Category:Electrical systems',
#  'Category:Electricity',
#  'Category:Electromagnetic components',
#  'Category:Electromagnetism',
#  'Category:Electronics',
#  'Category:Energy storage',
#  'Category:French inventions',
#  'Category:Human–machine interaction',
#  'Category:Humidity and hygrometry',
#  'Category:Infographics',
#  'Category:Physical quantities',
#  'Category:Psychrometrics',
#  'Category:Rectifiers',
#  'Category:Semiconductor devices',
#  'Category:Switches',
#  'Category:Voltage',
#  'Category:Weather'}
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1979348.txt'
# {'Category:Anatomical pathology',
#  'Category:Avena',
#  'Category:Cereals',
#  'Category:Chondropathies',
#  'Category:Concepts in physics',
#  'Category:Demulcents',
#  'Category:Fodder',
#  'Category:Inflammations',
#  'Category:Ligaments',
#  'Category:Medical signs',
#  'Category:Medical terminology',
#  'Category:Medicinal plants',
#  'Category:Oats',
#  'Category:Orthopedics stubs',
#  'Category:Patient',
#  'Category:Plants described in 1753',
#  'Category:Plasma physics',
#  'Category:Skeletal system',
#  'Category:Soft tissue',
#  'Category:Stability theory',
#  'Category:Staple foods',
#  'Category:Systems theory'}
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2136381.txt'
# {'Category:Acute pain',
#  'Category:Branches of biology',
#  'Category:Medical terminology',
#  'Category:Nociception',
#  'Category:Pain',
#  'Category:Pathology',
#  'Category:Patient',
#  'Category:Pharmacodynamics',
#  'Category:Sensory systems',
#  'Category:Suffering'}
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2175896.txt'
# {'Category:Alpha-1 blockers',
#  'Category:Analytical chemistry',
#  'Category:Antihypertensive agents',
#  'Category:Anxiolytics',
#  'Category:Biology',
#  'Category:Carboxamides',
#  'Category:Chemical kinetics',
#  'Category:Chemical properties',
#  'Category:Concepts in metaphysics',
#  'Category:Concepts in physics',
#  'Category:Curves',
#  'Category:Exponentials',
#  'Category:Furans',
#  'Category:Gender',
#  'Category:General topology',
#  'Category:Life sciences industry',
#  'Category:Metabolism',
#  'Category:Metric geometry',
#  'Category:Optical spectrum',
#  'Category:Pharmacokinetics',
#  'Category:Pharmacy',
#  'Category:Phenol ethers',
#  'Category:Physical quantities',
#  'Category:Piperazines',
#  'Category:Quinazolines',
#  'Category:Radioactivity',
#  'Category:SI base quantities',
#  'Category:Topology',
#  'Category:Vasodilators'}
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2303181.txt'
# {'Category:Artificial neural networks',
#  'Category:Communication',
#  'Category:Force',
#  'Category:Machine learning algorithms',
#  'Category:Mass',
#  'Category:Notation',
#  'Category:Physiology'}
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2315949.txt'
# {'Category:Annulenes',
#  'Category:Aromatic compounds',
#  'Category:Aromatic solvents',
#  'Category:Art materials',
#  'Category:Carcinogens',
#  'Category:Chemistry',
#  'Category:Commodity chemicals',
#  'Category:Dry lubricants',
#  'Category:Electrical conductors',
#  'Category:Emerging technologies',
#  'Category:Family',
#  'Category:GABAA receptor positive allosteric modulators',
#  'Category:Graphene',
#  'Category:Graphite',
#  'Category:Group IV semiconductors',
#  'Category:Hazardous air pollutants',
#  'Category:Hexagonal minerals',
#  'Category:Hydrocarbon solvents',
#  'Category:Hydrocarbons',
#  'Category:IARC Group 1 carcinogens',
#  'Category:Immunotoxins',
#  'Category:Industrial minerals',
#  'Category:Matter',
#  'Category:Molecular physics',
#  'Category:Molecules',
#  'Category:Monolayers',
#  'Category:Mutagens',
#  'Category:Native element minerals',
#  'Category:Non-petroleum based lubricants',
#  'Category:Occupational safety and health',
#  'Category:Petrochemicals',
#  'Category:Quantum Lattice models',
#  'Category:Quantum phases',
#  'Category:Refractory materials',
#  'Category:Renting',
#  'Category:Simple aromatic rings',
#  'Category:Six-membered rings',
#  'Category:Soil contamination',
#  'Category:Superhard materials',
#  'Category:Teratogens'}
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2350615.txt'
# {'Category:Hydrogen compounds',
#  'Category:Inorganic solvents',
#  'Category:Knowledge',
#  'Category:Liquids',
#  'Category:Oxides',
#  'Category:Oxygen compounds',
#  'Category:Research methods',
#  'Category:Scientific method',
#  'Category:Water'}
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2380540.txt'
# {'Category:Amine solvents',
#  'Category:Ammine complexes',
#  'Category:Aromatic bases',
#  'Category:Aromatic solvents',
#  'Category:Biotechnology',
#  'Category:Catalysts',
#  'Category:Chemical elements',
#  'Category:Coordination compounds',
#  'Category:Cubic minerals',
#  'Category:Curing agents',
#  'Category:DNA',
#  'Category:DNA-binding substances',
#  'Category:Drugs',
#  'Category:Foul-smelling chemicals',
#  'Category:Functional groups',
#  'Category:Garde manger',
#  'Category:Genetics',
#  'Category:Hazardous air pollutants',
#  'Category:Helices',
#  'Category:Native element minerals',
#  'Category:Nitrates',
#  'Category:Nitrogen cycle',
#  'Category:Noble metals',
#  'Category:Non-coordinating anions',
#  'Category:Nucleic acids',
#  'Category:Oxalates',
#  'Category:Oxoanions',
#  'Category:Phenanthridines',
#  'Category:Platinum',
#  'Category:Platinum compounds',
#  'Category:Platinum-based antineoplastic agents',
#  'Category:Precious metals',
#  'Category:Pyridines',
#  'Category:Quinolines',
#  'Category:Simple aromatic rings',
#  'Category:Transition metals',
#  'Category:Water quality indicators',
#  'Category:World Health Organization essential medicines'}
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2385429.txt'
# {'Category:Assumption',
#  'Category:Building',
#  'Category:Buildings and structures',
#  'Category:Concepts in logic',
#  'Category:Concepts in metaphysics',
#  'Category:Control theory',
#  'Category:Creativity',
#  'Category:Data modeling diagrams',
#  'Category:Electronic feedback',
#  'Category:Epistemology',
#  'Category:Feedback',
#  'Category:Lexical units',
#  'Category:Lexicography',
#  'Category:Names',
#  'Category:Objects',
#  'Category:Philosophical logic',
#  'Category:Pragmatics',
#  'Category:Real estate',
#  'Category:Semantic units',
#  'Category:Sources of knowledge',
#  'Category:Syntactic entities',
#  'Category:Units of linguistic morphology',
#  'Category:Words'}
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2409521.txt'
# {'Category:Causal inference',
#  'Category:Communication',
#  'Category:Design of experiments',
#  'Category:Elementary mathematics',
#  'Category:Emergence',
#  'Category:Experiments',
#  'Category:Interaction',
#  'Category:Logical consequence',
#  'Category:Mathematical terminology',
#  'Category:Numeral systems',
#  'Category:Science experiments',
#  'Category:Sociological terminology'}
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2458685.txt'
# {'Category:Addition',
#  'Category:Binary operations',
#  'Category:Ceramics',
#  'Category:Concepts in metaphysics',
#  'Category:Concepts in physics',
#  'Category:Condensed matter physics',
#  'Category:Design',
#  'Category:Diffraction',
#  'Category:Electromagnetic spectrum',
#  'Category:Elementary arithmetic',
#  'Category:Hardness tests',
#  'Category:Materials science',
#  'Category:Mathematical notation',
#  'Category:Matter',
#  'Category:Microwave technology',
#  'Category:Patterns',
#  'Category:Radio technology',
#  'Category:Solid mechanics',
#  'Category:Wireless'}
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2606453.txt'
# {'Category:Apple Inc. hardware',
#  'Category:Bones',
#  'Category:Bones of the lower limb',
#  'Category:Computer-related introductions in 2001',
#  'Category:Connective tissue',
#  'Category:Femur',
#  'Category:Foxconn',
#  'Category:Geography terminology',
#  'Category:Healthcare occupations',
#  'Category:IPod',
#  'Category:ITunes',
#  'Category:Landmarks',
#  'Category:Long bones',
#  'Category:Navigation',
#  'Category:Portable media players',
#  'Category:Positions of authority',
#  'Category:Products introduced in 2001',
#  'Category:Skeletal system',
#  'Category:Surgeons',
#  'Category:Tibia',
#  'Category:Wikipedia articles incorporating text from the 20th edition of '
#  "Gray's Anatomy (1918)"}
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2642361.txt'
# {'Category:Beds',
#  'Category:Blood',
#  'Category:Communication',
#  'Category:Crisis',
#  'Category:Hematology',
#  'Category:Human sexuality',
#  'Category:International relations',
#  'Category:Mattresses',
#  'Category:Security',
#  'Category:Sleep',
#  'Category:Strategic management',
#  'Category:Tissues (biology)',
#  'Category:Wireless locating'}
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2653915.txt'
# {'Category:Autonomy',
#  'Category:Causes of death',
#  'Category:Concepts in ethics',
#  'Category:Fashion',
#  'Category:Females',
#  'Category:Footwear',
#  'Category:Gender',
#  'Category:Legal defenses',
#  'Category:Males',
#  'Category:Medical ethics',
#  'Category:Medical terminology',
#  'Category:Men',
#  'Category:Orders of magnitude (time)',
#  'Category:Patient',
#  'Category:Protective gear',
#  'Category:Sex',
#  'Category:Shoes',
#  'Category:Solar calendars',
#  'Category:Stroke',
#  'Category:Terrestrial locomotion',
#  'Category:Tort law',
#  'Category:Women'}
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2794364.txt'
# {'Category:Analytical chemistry',
#  'Category:Chemical properties',
#  'Category:Means',
#  'Category:Medical terminology',
#  'Category:Patient',
#  'Category:Robust statistics',
#  'Category:Surgery'}
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2937632.txt'
# {'Category:Automobiles',
#  'Category:Building',
#  'Category:Causal inference',
#  'Category:Design of experiments',
#  'Category:Dielectrics',
#  'Category:Experiments',
#  'Category:Glass',
#  'Category:Hardware (mechanical)',
#  'Category:Headgear',
#  'Category:Mechanisms (engineering)',
#  'Category:Packaging materials',
#  'Category:Rooms',
#  'Category:Rotating shaft couplings',
#  'Category:Science experiments',
#  'Category:Sculpture materials',
#  'Category:Tableware',
#  'Category:Wheeled vehicles',
#  'Category:Windows'}
# '------------------------------'

# %% [markdown]
# ### Ranking der Kategorien
# Oberkategorien der Kategorien ermitteln. Anzahl der Überscheidungen = Anzahl Beziehungen
# Ranking nach Anzahl

# %%
def intersection(a,b):
    i = 0
    for e in a:
        if e in b:
            i += 1
    return i

def wiki_cats_sort_rel(f):
    terme = extract_term(f,nr_of_docs) 
    cats = set([c for (kw,f) in terme for c in noun2cat.get(kw)]) #Mit set werden doppelte Kategorien entfernt, Menge
    extended = {}
    relnumber = {}
    for cat in cats:
        family = [cat]
        family.extend(wiki_cats(cat)) #Funktion wiki_cats(), alle Kategorien eines Artikels ohne Stoppliste,...
        extended[cat] = family

    for cat in cats:
        relsize = 0
        for cat2 in cats:
            if cat == cat2:
                continue
            if intersection(extended[cat],extended[cat2]) > 0:
                relsize +=1
        relnumber[cat] = relsize
    return sorted(relnumber.items(),key = lambda x:x[1],reverse=True)
            
for f in filelist[150:170]:    
    pprint.pprint(f) 
    cts = wiki_cats_sort_rel(f) 
    pprint.pprint(cts)#Ausgabe der Kategorien, sortiert nit Anzahl der Überscheidungen
    pprint.pprint("------------------------------")
# Out:
# 'doi-cap-con/10.1155:2016:1875357.txt'
# [('Category:1990s fads and trends', 1),
#  ('Category:Systems', 1),
#  ('Category:2000s fads and trends', 1),
#  ('Category:Switches', 1),
#  ('Category:Concepts in metaphysics', 1),
#  ('Category:Electrical components', 1),
#  ('Category:Concepts in physics', 1),
#  ('Category:Data types', 1),
#  ('Category:Physical quantities', 1),
#  ('Category:Primitive types', 1),
#  ('Category:Units of information', 0),
#  ('Category:Human–machine interaction', 0),
#  ('Category:Waves', 0),
#  ('Category:Computers', 0),
#  ('Category:Binary arithmetic', 0),
#  ('Category:Consumer electronics', 0),
#  ('Category:SI base quantities', 0),
#  ('Category:Size', 0),
#  ('Category:Legal doctrines and principles', 0),
#  ('Category:Contract law', 0)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1901493.txt'
# [('Category:Tribology', 2),
#  ('Category:Force', 2),
#  ('Category:Friction', 2),
#  ('Category:Mechanical engineering', 1),
#  ('Category:Lubricants', 1),
#  ('Category:Lubrication', 1),
#  ('Category:Classical mechanics', 1),
#  ('Category:Petroleum products', 0),
#  ('Category:Balls', 0),
#  ('Category:Combustion', 0)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1925827.txt'
# [('Category:Topology', 2),
#  ('Category:Space', 2),
#  ('Category:Geometry', 2),
#  ('Category:Elementary shapes', 0),
#  ('Category:Quadrilaterals', 0)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1928465.txt'
# [('Category:Epistemology of science', 4),
#  ('Category:Cognition', 4),
#  ('Category:Sources of knowledge', 4),
#  ('Category:Perception', 3),
#  ('Category:Observation', 3),
#  ('Category:Telescopes', 2),
#  ('Category:Scientific method', 2),
#  ('Category:Philosophy of science', 2),
#  ('Category:Radiation', 2),
#  ('Category:Topology', 2),
#  ('Category:Light', 1),
#  ('Category:Astronomical imaging', 1),
#  ('Category:Metric geometry', 1),
#  ('Category:Weather', 1),
#  ('Category:General topology', 1),
#  ('Category:Astronomical instruments', 1),
#  ('Category:Assumption', 0),
#  ('Category:Curves', 0),
#  ('Category:Aptitude', 0),
#  ('Category:Orders of magnitude (time)', 0),
#  ('Category:Experiments', 0),
#  ('Category:17th-century introductions', 0),
#  ('Category:Science and technology in the Dutch Republic', 0),
#  ('Category:Dutch inventions', 0)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1962438.txt'
# [('Category:Electricity', 5),
#  ('Category:Voltage', 5),
#  ('Category:Capacitance', 4),
#  ('Category:Semiconductor devices', 4),
#  ('Category:Electromagnetism', 3),
#  ('Category:Electromagnetic components', 3),
#  ('Category:Electrical systems', 3),
#  ('Category:Switches', 3),
#  ('Category:Electrical components', 3),
#  ('Category:Physical quantities', 3),
#  ('Category:Atmospheric thermodynamics', 2),
#  ('Category:Diodes', 2),
#  ('Category:Infographics', 2),
#  ('Category:Electronics', 2),
#  ('Category:Psychrometrics', 1),
#  ('Category:Rectifiers', 1),
#  ('Category:Bus transport', 1),
#  ('Category:Diagrams', 1),
#  ('Category:Weather', 1),
#  ('Category:Human–machine interaction', 1),
#  ('Category:Buses', 1),
#  ('Category:Concepts in physics', 1),
#  ('Category:Energy storage', 0),
#  ('Category:Humidity and hygrometry', 0),
#  ('Category:1904 introductions', 0),
#  ('Category:Climate', 0),
#  ('Category:French inventions', 0)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:1979348.txt'
# [('Category:Oats', 3),
#  ('Category:Ligaments', 2),
#  ('Category:Cereals', 1),
#  ('Category:Skeletal system', 1),
#  ('Category:Avena', 1),
#  ('Category:Staple foods', 1),
#  ('Category:Soft tissue', 1),
#  ('Category:Stability theory', 0),
#  ('Category:Medical terminology', 0),
#  ('Category:Plasma physics', 0),
#  ('Category:Fodder', 0),
#  ('Category:Anatomical pathology', 0),
#  ('Category:Medical signs', 0),
#  ('Category:Plants described in 1753', 0),
#  ('Category:Inflammations', 0),
#  ('Category:Systems theory', 0),
#  ('Category:Patient', 0),
#  ('Category:Chondropathies', 0),
#  ('Category:Orthopedics stubs', 0),
#  ('Category:Demulcents', 0),
#  ('Category:Concepts in physics', 0),
#  ('Category:Medicinal plants', 0)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2136381.txt'
# [('Category:Pain', 4),
#  ('Category:Acute pain', 3),
#  ('Category:Nociception', 3),
#  ('Category:Suffering', 3),
#  ('Category:Sensory systems', 1),
#  ('Category:Pathology', 1),
#  ('Category:Branches of biology', 1),
#  ('Category:Medical terminology', 0),
#  ('Category:Pharmacodynamics', 0),
#  ('Category:Patient', 0)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2175896.txt'
# [('Category:Biology', 2),
#  ('Category:Topology', 2),
#  ('Category:Chemical properties', 1),
#  ('Category:Pharmacokinetics', 1),
#  ('Category:Vasodilators', 1),
#  ('Category:Pharmacy', 1),
#  ('Category:Piperazines', 1),
#  ('Category:Metric geometry', 1),
#  ('Category:Furans', 1),
#  ('Category:Antihypertensive agents', 1),
#  ('Category:Life sciences industry', 1),
#  ('Category:General topology', 1),
#  ('Category:Gender', 1),
#  ('Category:Concepts in physics', 1),
#  ('Category:Physical quantities', 1),
#  ('Category:Analytical chemistry', 1),
#  ('Category:Phenol ethers', 0),
#  ('Category:Metabolism', 0),
#  ('Category:SI base quantities', 0),
#  ('Category:Alpha-1 blockers', 0),
#  ('Category:Curves', 0),
#  ('Category:Exponentials', 0),
#  ('Category:Quinazolines', 0),
#  ('Category:Anxiolytics', 0),
#  ('Category:Optical spectrum', 0),
#  ('Category:Carboxamides', 0),
#  ('Category:Concepts in metaphysics', 0),
#  ('Category:Radioactivity', 0),
#  ('Category:Chemical kinetics', 0)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2303181.txt'
# [('Category:Force', 1),
#  ('Category:Machine learning algorithms', 1),
#  ('Category:Mass', 1),
#  ('Category:Artificial neural networks', 1),
#  ('Category:Notation', 0),
#  ('Category:Communication', 0),
#  ('Category:Physiology', 0)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2315949.txt'
# [('Category:Molecules', 5),
#  ('Category:Aromatic compounds', 4),
#  ('Category:Aromatic solvents', 3),
#  ('Category:Carcinogens', 3),
#  ('Category:Superhard materials', 2),
#  ('Category:Petrochemicals', 2),
#  ('Category:Chemistry', 2),
#  ('Category:Electrical conductors', 2),
#  ('Category:Hydrocarbon solvents', 2),
#  ('Category:Molecular physics', 2),
#  ('Category:Simple aromatic rings', 2),
#  ('Category:Refractory materials', 2),
#  ('Category:Teratogens', 2),
#  ('Category:Graphite', 2),
#  ('Category:Matter', 1),
#  ('Category:Commodity chemicals', 1),
#  ('Category:IARC Group 1 carcinogens', 1),
#  ('Category:Six-membered rings', 1),
#  ('Category:Graphene', 1),
#  ('Category:Non-petroleum based lubricants', 1),
#  ('Category:Hydrocarbons', 1),
#  ('Category:Quantum Lattice models', 1),
#  ('Category:Quantum phases', 1),
#  ('Category:Dry lubricants', 1),
#  ('Category:Native element minerals', 1),
#  ('Category:Mutagens', 0),
#  ('Category:Group IV semiconductors', 0),
#  ('Category:Occupational safety and health', 0),
#  ('Category:Soil contamination', 0),
#  ('Category:Emerging technologies', 0),
#  ('Category:Renting', 0),
#  ('Category:Monolayers', 0),
#  ('Category:Annulenes', 0),
#  ('Category:GABAA receptor positive allosteric modulators', 0),
#  ('Category:Family', 0),
#  ('Category:Hazardous air pollutants', 0),
#  ('Category:Immunotoxins', 0),
#  ('Category:Industrial minerals', 0),
#  ('Category:Hexagonal minerals', 0),
#  ('Category:Art materials', 0)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2350615.txt'
# [('Category:Oxygen compounds', 2),
#  ('Category:Research methods', 1),
#  ('Category:Oxides', 1),
#  ('Category:Water', 1),
#  ('Category:Hydrogen compounds', 1),
#  ('Category:Scientific method', 1),
#  ('Category:Liquids', 1),
#  ('Category:Inorganic solvents', 0),
#  ('Category:Knowledge', 0)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2380540.txt'
# [('Category:Coordination compounds', 4),
#  ('Category:Platinum', 4),
#  ('Category:DNA', 3),
#  ('Category:Aromatic solvents', 3),
#  ('Category:DNA-binding substances', 3),
#  ('Category:Precious metals', 3),
#  ('Category:Transition metals', 3),
#  ('Category:Oxoanions', 2),
#  ('Category:Platinum compounds', 2),
#  ('Category:Noble metals', 2),
#  ('Category:Foul-smelling chemicals', 2),
#  ('Category:Aromatic bases', 2),
#  ('Category:Non-coordinating anions', 2),
#  ('Category:Simple aromatic rings', 2),
#  ('Category:Quinolines', 1),
#  ('Category:Drugs', 1),
#  ('Category:Chemical elements', 1),
#  ('Category:Amine solvents', 1),
#  ('Category:Platinum-based antineoplastic agents', 1),
#  ('Category:Nucleic acids', 1),
#  ('Category:World Health Organization essential medicines', 1),
#  ('Category:Phenanthridines', 1),
#  ('Category:Ammine complexes', 1),
#  ('Category:Nitrates', 1),
#  ('Category:Genetics', 1),
#  ('Category:Helices', 0),
#  ('Category:Water quality indicators', 0),
#  ('Category:Cubic minerals', 0),
#  ('Category:Catalysts', 0),
#  ('Category:Oxalates', 0),
#  ('Category:Garde manger', 0),
#  ('Category:Nitrogen cycle', 0),
#  ('Category:Biotechnology', 0),
#  ('Category:Hazardous air pollutants', 0),
#  ('Category:Pyridines', 0),
#  ('Category:Functional groups', 0),
#  ('Category:Curing agents', 0),
#  ('Category:Native element minerals', 0)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2385429.txt'
# [('Category:Words', 5),
#  ('Category:Lexical units', 4),
#  ('Category:Units of linguistic morphology', 4),
#  ('Category:Semantic units', 4),
#  ('Category:Syntactic entities', 3),
#  ('Category:Concepts in metaphysics', 2),
#  ('Category:Concepts in logic', 2),
#  ('Category:Feedback', 2),
#  ('Category:Objects', 1),
#  ('Category:Control theory', 1),
#  ('Category:Philosophical logic', 1),
#  ('Category:Pragmatics', 1),
#  ('Category:Sources of knowledge', 1),
#  ('Category:Lexicography', 1),
#  ('Category:Epistemology', 1),
#  ('Category:Electronic feedback', 1),
#  ('Category:Assumption', 0),
#  ('Category:Building', 0),
#  ('Category:Buildings and structures', 0),
#  ('Category:Data modeling diagrams', 0),
#  ('Category:Real estate', 0),
#  ('Category:Creativity', 0),
#  ('Category:Names', 0)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2409521.txt'
# [('Category:Science experiments', 2),
#  ('Category:Experiments', 1),
#  ('Category:Interaction', 1),
#  ('Category:Design of experiments', 1),
#  ('Category:Emergence', 1),
#  ('Category:Elementary mathematics', 0),
#  ('Category:Logical consequence', 0),
#  ('Category:Causal inference', 0),
#  ('Category:Mathematical terminology', 0),
#  ('Category:Numeral systems', 0),
#  ('Category:Sociological terminology', 0),
#  ('Category:Communication', 0)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2458685.txt'
# [('Category:Radio technology', 2),
#  ('Category:Microwave technology', 1),
#  ('Category:Elementary arithmetic', 1),
#  ('Category:Patterns', 1),
#  ('Category:Design', 1),
#  ('Category:Condensed matter physics', 1),
#  ('Category:Materials science', 1),
#  ('Category:Wireless', 1),
#  ('Category:Addition', 1),
#  ('Category:Matter', 0),
#  ('Category:Diffraction', 0),
#  ('Category:Ceramics', 0),
#  ('Category:Mathematical notation', 0),
#  ('Category:Concepts in metaphysics', 0),
#  ('Category:Solid mechanics', 0),
#  ('Category:Concepts in physics', 0),
#  ('Category:Binary operations', 0),
#  ('Category:Hardness tests', 0),
#  ('Category:Electromagnetic spectrum', 0)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2606453.txt'
# [('Category:Bones', 3),
#  ('Category:Bones of the lower limb', 2),
#  ('Category:Geography terminology', 2),
#  ('Category:IPod', 2),
#  ('Category:Navigation', 2),
#  ('Category:Landmarks', 2),
#  ('Category:Femur', 2),
#  ('Category:Tibia', 2),
#  ('Category:Apple Inc. hardware', 1),
#  ('Category:Products introduced in 2001', 1),
#  ('Category:Long bones', 1),
#  ('Category:Connective tissue', 1),
#  ('Category:Computer-related introductions in 2001', 1),
#  ('Category:Portable media players', 1),
#  ('Category:Skeletal system', 1),
#  ('Category:Foxconn', 0),
#  ('Category:Wikipedia articles incorporating text from the 20th edition of '
#   "Gray's Anatomy (1918)",
#   0),
#  ('Category:Positions of authority', 0),
#  ('Category:Surgeons', 0),
#  ('Category:ITunes', 0),
#  ('Category:Healthcare occupations', 0)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2642361.txt'
# [('Category:Sleep', 2),
#  ('Category:Blood', 2),
#  ('Category:Crisis', 2),
#  ('Category:Beds', 2),
#  ('Category:Hematology', 1),
#  ('Category:Tissues (biology)', 1),
#  ('Category:Mattresses', 1),
#  ('Category:Communication', 1),
#  ('Category:Security', 1),
#  ('Category:Strategic management', 1),
#  ('Category:Human sexuality', 0),
#  ('Category:International relations', 0),
#  ('Category:Wireless locating', 0)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2653915.txt'
# [('Category:Males', 4),
#  ('Category:Females', 3),
#  ('Category:Men', 2),
#  ('Category:Sex', 2),
#  ('Category:Gender', 2),
#  ('Category:Footwear', 2),
#  ('Category:Stroke', 1),
#  ('Category:Women', 1),
#  ('Category:Shoes', 1),
#  ('Category:Causes of death', 1),
#  ('Category:Fashion', 1),
#  ('Category:Medical terminology', 0),
#  ('Category:Solar calendars', 0),
#  ('Category:Tort law', 0),
#  ('Category:Medical ethics', 0),
#  ('Category:Legal defenses', 0),
#  ('Category:Protective gear', 0),
#  ('Category:Autonomy', 0),
#  ('Category:Orders of magnitude (time)', 0),
#  ('Category:Concepts in ethics', 0),
#  ('Category:Terrestrial locomotion', 0),
#  ('Category:Patient', 0)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2794364.txt'
# [('Category:Chemical properties', 1),
#  ('Category:Analytical chemistry', 1),
#  ('Category:Means', 0),
#  ('Category:Surgery', 0),
#  ('Category:Robust statistics', 0),
#  ('Category:Medical terminology', 0),
#  ('Category:Patient', 0)]
# '------------------------------'
# 'doi-cap-con/10.1155:2016:2937632.txt'
# [('Category:Science experiments', 2),
#  ('Category:Hardware (mechanical)', 2),
#  ('Category:Mechanisms (engineering)', 2),
#  ('Category:Windows', 1),
#  ('Category:Experiments', 1),
#  ('Category:Dielectrics', 1),
#  ('Category:Building', 1),
#  ('Category:Rotating shaft couplings', 1),
#  ('Category:Design of experiments', 1),
#  ('Category:Automobiles', 1),
#  ('Category:Wheeled vehicles', 1),
#  ('Category:Glass', 1),
#  ('Category:Rooms', 1),
#  ('Category:Headgear', 0),
#  ('Category:Tableware', 0),
#  ('Category:Packaging materials', 0),
#  ('Category:Causal inference', 0),
#  ('Category:Sculpture materials', 0)]
# '------------------------------'
